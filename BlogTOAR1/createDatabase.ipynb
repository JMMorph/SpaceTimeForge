# %%
import json
import pandas as pd
import requests

files_path = 'files/'
url="https://toar-data.fz-juelich.de/api/v2/"

variables_url = url + 'variables/'
stations_url = url + 'stationmeta/'
timeseries_url = url + 'timeseries/'
timeseries_data_url = url + 'data/timeseries/'

try:
    with open(files_path + 'toar_apikey.txt', 'r') as f:
        token = f.read().strip()
except FileNotFoundError:
    token = ''
    print(f"API key file not found. Please ensure 'toar_apikey.txt' exists in the {files_path} directory.")

headers = {'AccessToken': token}

# %% [markdown]
# # Variables metadata

# %%
params = { 'limit': 'None'}
response = requests.get(variables_url, headers=headers, params=params)

# %%
if response.status_code == 200:
    variables_json = response.json()
    
    print(f'Correctly loaded metadata from {len(variables_json)} variables:')
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Correctly loaded metadata from 37 variables:

# %%
variables_df = pd.DataFrame(variables_json)
variables_df.rename(columns={'id': 'variable_id'}, inplace=True)
variables_df.head(10)
# Out:
#       name                       longname displayname  \
# 0  benzene                        benzene     Benzene
# 1       co                carbon monoxide          CO
# 2       no              nitrogen monoxide          NO
# 3      pm1  particles up to 1 µm diameter        PM 1
# 4       o3                          ozone       Ozone
# 5      no2               nitrogen dioxide         NO2
# 6  toluene                        toluene     Toluene
# 7      so2                Sulphur dioxide         SO2
# 8   ethane                         Ethane      Ethane
# 9  propane                        Propane     Propane
#
#                                     cf_standardname       units  \
# 0                   mole_fraction_of_benzene_in_air  nmol mol-1
# 1           mole_fraction_of_carbon_monoxide_in_air  nmol mol-1
# 2         mole_fraction_of_nitrogen_monoxide_in_air  nmol mol-1
# 3  mass_concentration_of_pm1_ambient_aerosol_in_air      µg m-3
# 4                     mole_fraction_of_ozone_in_air  nmol mol-1
# 5          mole_fraction_of_nitrogen_dioxide_in_air  nmol mol-1
# 6                   mole_fraction_of_toluene_in_air  nmol mol-1
# 7            mole_fraction_of_sulfur_dioxide_in_air  nmol mol-1
# 8                    mole_fraction_of_ethane_in_air  nmol mol-1
# 9                   mole_fraction_of_propane_in_air  nmol mol-1
#
#   chemical_formula  variable_id
# 0             C6H6            1
# 1               CO            2
# 2               NO            3
# 3                             4
# 4               O3            5
# 5              NO2            6
# 6             C7H8            7
# 7              SO2            8
# 8             C2H6            9
# 9             C3H8           10

# %% [markdown]
# # Bounding Box
# (min_lat, min_lon, max_lat, max_lon in degrees_north/degrees_east)

# %%
min_lat = 19.0487187
max_lat = 19.5927572
min_lon = -99.3649242
max_lon = -98.9403028

# %% [markdown]
# # Stations metadata

# %%
params = {
    'limit': 'None',
    'bounding_box': f'{min_lat},{min_lon},{max_lat},{max_lon}'
}

response = requests.get(stations_url, headers=headers, params=params)

# %%
if response.status_code == 200:
    stations_json = response.json()
    
    print(f'Correctly loaded metadata from {len(stations_json)} stations:')
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Correctly loaded metadata from 42 stations:

# %%
stations_data = []
for s in stations_json:
    d = {
        'id': s.get('id'),
        'name': s.get('name'),
        'lat': s.get('coordinates', {}).get('lat',-1),
        'lon': s.get('coordinates', {}).get('lng',-1),
        'alt': s.get('coordinates', {}).get('alt',-1),
        'country': s.get('country'),
        'state': s.get('state'),
        'type': s.get('type', s.get('type_of_area'))
    }
    stations_data.append(d)

# optional: convert to DataFrame for easy inspection
stations_df = pd.DataFrame(stations_data)
stations_df.head(5)
# Out:
#      id            name       lat      lon     alt country             state  \
# 0    17        Pedregal  19.32515 -99.2041  2326.0  Mexico  Distrito Federal
# 1  1318        Santa Fe  19.35730 -99.2628  -999.0  Mexico
# 2  1634         Tlahuac  19.24640 -99.0100  -999.0  Mexico
# 3  1712        Atizapán  19.57700 -99.2542  -999.0  Mexico
# 4  1873  UAM Xochimilco  19.30440 -99.0738  -999.0  Mexico
#
#       type
# 0  traffic
# 1  unknown
# 2  unknown
# 3  unknown
# 4  unknown

# %% [markdown]
# # Time Series

# %%
params = {
    'limit': 'None',
    'station_id': ','.join(stations_df['id'].astype('str').tolist()),
    }

response = requests.get(timeseries_url, headers=headers, params=params)

# %%
if response.status_code == 200:
    timeseries_json = response.json()
    
    print(f'Correctly loaded metadata from {len(timeseries_json)} timeseries:')
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Correctly loaded metadata from 786 timeseries:

# %%
timeseries_dict = []

# extract relevant fields
for s in timeseries_json:
    d = {
        'timeseries_id': s.get('id'),
        'variable_id': s.get('variable', {}).get('id'),
        'id': s.get('station', {}).get('id'),
        'sampling_frequency': s.get('sampling_frequency'),
        'start_date': s.get('data_start_date'),
        'end_date': s.get('data_end_date'),
        
    }
    timeseries_dict.append(d)

# convert to DataFrame
timeseries_df = pd.DataFrame(timeseries_dict)
timeseries_df.head(5)
# Out:
#    timeseries_id  variable_id    id                        sampling_frequency  \
# 0             18            5    17                                    hourly
# 1            681           19  1318  irregular data samples of varying length
# 2            682           13  1318  irregular data samples of varying length
# 3            683            2  1318  irregular data samples of varying length
# 4            684            8  1318  irregular data samples of varying length
#
#                   start_date                   end_date
# 0  1986-01-17T07:00:00+00:00  2016-01-01T06:00:00+00:00
# 1  2016-05-04T22:00:00+00:00  2022-09-29T21:00:00+00:00
# 2  2016-05-04T22:00:00+00:00  2022-09-29T21:00:00+00:00
# 3  2016-03-29T12:00:00+00:00  2022-09-29T21:00:00+00:00
# 4  2016-03-29T08:00:00+00:00  2022-09-29T21:00:00+00:00

# %%
# Merge timeseries, stations and variables data
timeseries_df = timeseries_df.merge(variables_df.rename(columns={'name':'variable_name'}),
                    on='variable_id', 
                    how='left')\
                        .merge(stations_df.rename(columns={'name':'station_name'}),
                               on='id', 
                               how='left')

# %%
timeseries_df.groupby(['variable_name']).agg({'start_date': 'min',
                                              'end_date': 'max',
                                              'timeseries_id': 'count'})
# Out:
#                                 start_date                   end_date  \
# variable_name
# cloudcover       2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# co               2016-03-10T08:00:00+00:00  2022-09-29T21:00:00+00:00
# humidity         2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# irradiance       2006-01-01T07:00:00+00:00  2021-12-31T23:00:00+00:00
# leaf_area_index  2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# no2              2016-03-10T08:00:00+00:00  2022-09-29T21:00:00+00:00
# o3               1986-01-17T07:00:00+00:00  2022-09-29T21:00:00+00:00
# pblheight        2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# pm10             2016-03-10T08:00:00+00:00  2022-10-10T16:00:00+00:00
# pm2p5            2016-03-10T08:00:00+00:00  2022-10-04T13:00:00+00:00
# press            2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# relhum           2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# so2              2016-03-10T08:00:00+00:00  2022-09-29T21:00:00+00:00
# tdew2m           2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# temp             2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# totprecip        2006-01-01T07:00:00+00:00  2021-12-31T23:00:00+00:00
# u                2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# v                2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# wdir             2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
# wspeed           2000-01-01T00:00:00+00:00  2022-12-31T23:00:00+00:00
#
#                  timeseries_id
# variable_name
# cloudcover                  42
# co                          37
# humidity                    42
# irradiance                  42
# leaf_area_index             42
# no2                         36
# o3                          39
# pblheight                   42
# pm10                        24
# pm2p5                       26
# press                       42
# relhum                      42
# so2                         36
# tdew2m                      42
# temp                        42
# totprecip                   42
# u                           42
# v                           42
# wdir                        42
# wspeed                      42

# %%
# filter only data from pollutants
timeseries_df.query('variable_name.isin(["o3","co","no2","so2","pm2p5","pm10"])', inplace=True)
timeseries_df.groupby(['variable_name']).agg({'start_date': 'min', 
                                              'end_date': 'max', 
                                              'timeseries_id': 'count'})
# Out:
#                               start_date                   end_date  \
# variable_name
# co             2016-03-10T08:00:00+00:00  2022-09-29T21:00:00+00:00
# no2            2016-03-10T08:00:00+00:00  2022-09-29T21:00:00+00:00
# o3             1986-01-17T07:00:00+00:00  2022-09-29T21:00:00+00:00
# pm10           2016-03-10T08:00:00+00:00  2022-10-10T16:00:00+00:00
# pm2p5          2016-03-10T08:00:00+00:00  2022-10-04T13:00:00+00:00
# so2            2016-03-10T08:00:00+00:00  2022-09-29T21:00:00+00:00
#
#                timeseries_id
# variable_name
# co                        37
# no2                       36
# o3                        39
# pm10                      24
# pm2p5                     26
# so2                       36

# %%
timeseries_df.to_csv(files_path + 'timeseries_metadata.csv', index=False)

# %% [markdown]
# # Time Series Data

# %%
import time

params = {
    'limit': 'None',
    'format': 'csv',
    }

for _, row in timeseries_df.iterrows():
    
    # request the data from TOAR  API
    ts_id = str(row['timeseries_id'])
    response = requests.get(timeseries_data_url + ts_id, 
                            headers=headers,
                            params=params)
    

    if response.status_code == 200:
        
        # decode bytes to string (utf-8, replace invalid bytes)
        text = response.content.decode('utf-8', errors='replace') if isinstance(response.content, (bytes, bytearray)) else str(response.content)
        metadata = [line[1::] for line in text.splitlines() if line.startswith('#')]
        metadata = json.loads('\n'.join(metadata))
        data = [line for line in text.splitlines() if not line.startswith('#')]
        data = '\n'.join(data)
        
        # save CSV with the timeseries id in the filename
        filename = files_path + f"timeseries_{metadata['id']}.csv"
        
        with open(filename, "wb") as fh:
            fh.write(data.encode('utf-8'))
        print(f"Saved CSV to {filename} ({len(response.content)} bytes)")
        time.sleep(5)
    else:
        print(f"Failed to get CSV: {response.status_code} - {getattr(response, 'text', '')}")
# Out:
# Saved CSV to files/timeseries_18.csv (15544425 bytes)
# Saved CSV to files/timeseries_681.csv (1212011 bytes)
# Saved CSV to files/timeseries_682.csv (1225885 bytes)
# Saved CSV to files/timeseries_683.csv (1493190 bytes)
# Saved CSV to files/timeseries_14836.csv (316200 bytes)
# Saved CSV to files/timeseries_14837.csv (307976 bytes)
# Saved CSV to files/timeseries_14838.csv (308957 bytes)
# Saved CSV to files/timeseries_14839.csv (310060 bytes)
# Saved CSV to files/timeseries_14840.csv (318260 bytes)
# Saved CSV to files/timeseries_14863.csv (262609 bytes)
# Saved CSV to files/timeseries_14864.csv (257037 bytes)
# Saved CSV to files/timeseries_14865.csv (257087 bytes)
# Saved CSV to files/timeseries_14866.csv (254610 bytes)
# Saved CSV to files/timeseries_14867.csv (254275 bytes)
# Saved CSV to files/timeseries_14870.csv (302141 bytes)
# Saved CSV to files/timeseries_14871.csv (285691 bytes)
# Saved CSV to files/timeseries_14872.csv (305427 bytes)
# Saved CSV to files/timeseries_14873.csv (301462 bytes)
# Saved CSV to files/timeseries_14874.csv (235330 bytes)
# Saved CSV to files/timeseries_14875.csv (237219 bytes)
# Saved CSV to files/timeseries_14933.csv (241192 bytes)
# Saved CSV to files/timeseries_14934.csv (254711 bytes)
# Saved CSV to files/timeseries_14935.csv (251628 bytes)
# Saved CSV to files/timeseries_14936.csv (257060 bytes)
# Saved CSV to files/timeseries_14937.csv (254171 bytes)
# Saved CSV to files/timeseries_14938.csv (224122 bytes)
# Saved CSV to files/timeseries_14954.csv (280633 bytes)
# Saved CSV to files/timeseries_14955.csv (302045 bytes)
# Saved CSV to files/timeseries_14956.csv (297190 bytes)
# Saved CSV to files/timeseries_14957.csv (248798 bytes)
# Saved CSV to files/timeseries_14958.csv (235457 bytes)
# Saved CSV to files/timeseries_14959.csv (261772 bytes)
# Saved CSV to files/timeseries_14960.csv (250898 bytes)
# Saved CSV to files/timeseries_14961.csv (256202 bytes)
# Saved CSV to files/timeseries_14962.csv (250424 bytes)
# Saved CSV to files/timeseries_14963.csv (248720 bytes)
# Saved CSV to files/timeseries_14964.csv (245965 bytes)
# Saved CSV to files/timeseries_15024.csv (304832 bytes)
# Saved CSV to files/timeseries_15025.csv (294130 bytes)
# Saved CSV to files/timeseries_15026.csv (315619 bytes)
# Saved CSV to files/timeseries_15081.csv (309163 bytes)
# Saved CSV to files/timeseries_15082.csv (310688 bytes)
# Saved CSV to files/timeseries_15083.csv (281381 bytes)
# Saved CSV to files/timeseries_15084.csv (280403 bytes)
# Saved CSV to files/timeseries_15085.csv (306230 bytes)

# %% [markdown]
# # Build database

# %%
df = pd.DataFrame()
for _, row in timeseries_df.iterrows():
    ts_id = str(row['timeseries_id'])
    station = str(row['station_name'])
    variable = str(row['variable_name'])
    ts_df = pd.read_csv(files_path + f"timeseries_{ts_id}.csv",parse_dates=['datetime'])
    ts_df = ts_df[['datetime','value']].assign(station=station, variable=variable, inplace=True)
    
    df = pd.concat([df, ts_df], ignore_index=True)

# %%
df = df.groupby(['station','variable','datetime']).agg({'value':list}).reset_index()
df['value'] = df['value'].apply(lambda x: x[0] if len(x) == 1 else max(x))

# %%
df.to_csv(files_path + 'timeseries_data.csv', index=False)
